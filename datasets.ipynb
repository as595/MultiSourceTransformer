# %%
from MiraBest_F import MBFRFull as MBFRFull_F
from MiraBest_N import MBFRFull as MBFRFull_N
from MiraBest_FN import MBFRFull as MBFRFull_FN

# %%
import torch
import torchvision
from torchvision import datasets, transforms
from PIL import Image
import numpy as np
import pylab as pl

# %%
from utils import *
from transforms import MBtransforms

# %% [markdown]
# ---
#
# ### MiraBest-F

# %%
config_file = './configs/mirabest_F.cfg'
config_dict, config = parse_config(config_file)

# %%
mb_transforms = MBtransforms(config_dict)
transform_F = mb_transforms.transform()

# %%
F_data = MBFRFull_F('../data', train=True, download=True, transform=transform_F)
F_loader = torch.utils.data.DataLoader(F_data, batch_size=3)

# %%
images_F, labels_F = next(iter(F_loader))
print(images_F.size())
print(len(F_data))
# Out:
# torch.Size([3, 1, 140, 140])
# 1069

# %%
fig, (ax1, ax2, ax3) = pl.subplots(figsize=(8, 3), ncols=3)
ax1.imshow(images_F[0,0,:,:], cmap='cubehelix')
ax2.imshow(images_F[1,0,:,:], cmap='cubehelix')
ax3.imshow(images_F[2,0,:,:], cmap='cubehelix')
ax1.set_xticks([])
ax1.set_yticks([])
ax2.set_xticks([])
ax2.set_yticks([])
ax3.set_xticks([])
ax3.set_yticks([])
pl.tight_layout()
pl.show()

# %% [markdown]
# ---
#
# ### MiraBest-N

# %%
config_file = './configs/mirabest_N.cfg'
config_dict, config = parse_config(config_file)

# %%
mb_transforms = MBtransforms(config_dict)
transform_N = mb_transforms.transform()

# %%
N_data = MBFRFull_N('../data', train=True, download=True, transform=transform_N)
N_loader = torch.utils.data.DataLoader(N_data, batch_size=3)

# %%
images_N, labels_N = next(iter(N_loader))
print(images_N.size())
print(len(N_data))
# Out:
# torch.Size([3, 1, 140, 140])
# 1069

# %%
fig, (ax1, ax2, ax3) = pl.subplots(figsize=(8, 3), ncols=3)
ax1.imshow(images_N[0,0,:,:], cmap='cubehelix')
ax2.imshow(images_N[1,0,:,:], cmap='cubehelix')
ax3.imshow(images_N[2,0,:,:], cmap='cubehelix')
ax1.set_xticks([])
ax1.set_yticks([])
ax2.set_xticks([])
ax2.set_yticks([])
ax3.set_xticks([])
ax3.set_yticks([])
pl.tight_layout()
pl.show()

# %% [markdown]
# ---
#
# ### MiraBest-FN-I

# %%
config_file = './configs/mirabest_fn-i.cfg'
config_dict, config = parse_config(config_file)

# %%
mb_transforms = MBtransforms(config_dict)
transform = mb_transforms.transform()

# %%
data_F = MBFRFull_F('../data', train=True, download=True, transform=transform['transform_F'])
data_N = MBFRFull_N('../data', train=True, download=True, transform=transform['transform_N'])
FN_data = torch.utils.data.ConcatDataset([data_F, data_N])

FN_loader = torch.utils.data.DataLoader(FN_data, batch_size=3, shuffle=True)

# %%
images_FN_I, labels_FN_I = next(iter(FN_loader))
print(images_FN_I.size())
print(len(FN_data))
# Out:
# torch.Size([3, 1, 140, 140])
# 2138

# %%
fig, (ax1, ax2, ax3) = pl.subplots(figsize=(8, 3), ncols=3)
ax1.imshow(images_FN_I[0,0,:,:], cmap='cubehelix')
ax2.imshow(images_FN_I[1,0,:,:], cmap='cubehelix')
ax3.imshow(images_FN_I[2,0,:,:], cmap='cubehelix')
ax1.set_xticks([])
ax1.set_yticks([])
ax2.set_xticks([])
ax2.set_yticks([])
ax3.set_xticks([])
ax3.set_yticks([])
pl.tight_layout()
pl.show()

# %% [markdown]
# ---
#
# ### MiraBest-FN-C / MiraBest-FN-S
#
# (same data shape, different architectures)

# %%
config_file = './configs/mirabest_fn-c.cfg'
config_dict, config = parse_config(config_file)

# %%
mb_transforms = MBtransforms(config_dict)
transform = mb_transforms.transform()

# %%
FN_data = MBFRFull_FN('../data', train=True, download=True, transform=transform)
FN_loader = torch.utils.data.DataLoader(FN_data, batch_size=6)

# %%
images_FN, labels_FN = next(iter(FN_loader))
print(images_FN.size())
print(len(FN_data))
# Out:
# torch.Size([6, 2, 140, 140])
# 1069

# %%
fig, (ax1, ax2, ax3) = pl.subplots(figsize=(8, 3), ncols=3)
ax1.imshow(images_FN[0,0,:,:], cmap='cubehelix')
ax2.imshow(images_FN[1,0,:,:], cmap='cubehelix')
ax3.imshow(images_FN[2,0,:,:], cmap='cubehelix')
ax1.set_xticks([])
ax1.set_yticks([])
ax2.set_xticks([])
ax2.set_yticks([])
ax3.set_xticks([])
ax3.set_yticks([])
pl.tight_layout()
pl.show()

fig, (ax1, ax2, ax3) = pl.subplots(figsize=(8, 3), ncols=3)
ax1.imshow(images_FN[0,1,:,:], cmap='cubehelix')
ax2.imshow(images_FN[1,1,:,:], cmap='cubehelix')
ax3.imshow(images_FN[2,1,:,:], cmap='cubehelix')
ax1.set_xticks([])
ax1.set_yticks([])
ax2.set_xticks([])
ax2.set_yticks([])
ax3.set_xticks([])
ax3.set_yticks([])
pl.tight_layout()
pl.show()

# %%
fig, (ax1, ax2, ax3) = pl.subplots(figsize=(8, 3), ncols=3)
ax1.imshow(images_FN[3,0,:,:], cmap='cubehelix')
ax2.imshow(images_FN[4,0,:,:], cmap='cubehelix')
ax3.imshow(images_FN[5,0,:,:], cmap='cubehelix')
ax1.set_xticks([])
ax1.set_yticks([])
ax2.set_xticks([])
ax2.set_yticks([])
ax3.set_xticks([])
ax3.set_yticks([])
pl.tight_layout()
pl.show()

fig, (ax1, ax2, ax3) = pl.subplots(figsize=(8, 3), ncols=3)
ax1.imshow(images_FN[3,1,:,:], cmap='cubehelix')
ax2.imshow(images_FN[4,1,:,:], cmap='cubehelix')
ax3.imshow(images_FN[5,1,:,:], cmap='cubehelix')
ax1.set_xticks([])
ax1.set_yticks([])
ax2.set_xticks([])
ax2.set_yticks([])
ax3.set_xticks([])
ax3.set_yticks([])
pl.tight_layout()
pl.show()

# %% [markdown]
# ---
# ### MiraBest_full vs. MiraBest_F

# %%
from MiraBest import MBFRConfident as MB1
from MiraBest_F import MBFRConfident as MB2

# %%
data_1 = MB1('../data', train=True, download=True)
data_2 = MB2('../data', train=True, download=True)
# Out:
# Files already downloaded and verified

# %%
loader_1 = torch.utils.data.DataLoader(data_1, batch_size=6)
loader_2 = torch.utils.data.DataLoader(data_2, batch_size=6)

# %%
data_2.filenames[0:3]
# Out:
# [np.str_('./MiraBest_F/PNG/Scaled_Final/100_123.251+043.797_0.1281_0034.09.png'),
#  np.str_('./MiraBest_F/PNG/Scaled_Final/100_161.928+043.781_0.0858_0112.61.png'),
#  np.str_('./MiraBest_F/PNG/Scaled_Final/100_163.937+045.400_0.0636_0096.40.png')]
